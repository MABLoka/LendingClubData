# %%
import pandas as pd

df = pd.read_csv('../data/loan_raw.csv')
df.shape
df.head()
# Out:
# C:\Users\mahfo\AppData\Local\Temp\ipykernel_25716\1549293680.py:3: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/loan_raw.csv')
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# 1     11.99       820.28     C        C1  ...                            NaN
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 151 entries, id to settlement_term
# dtypes: float64(113), object(38)
# memory usage: 2.5+ GB
#        member_id     loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count        0.0  2.260668e+06  2.260668e+06     2.260668e+06  2.260668e+06
# mean         NaN  1.504693e+04  1.504166e+04     1.502344e+04  1.309283e+01
# std          NaN  9.190245e+03  9.188413e+03     9.192332e+03  4.832138e+00
# min          NaN  5.000000e+02  5.000000e+02     0.000000e+00  5.310000e+00
# 25%          NaN  8.000000e+03  8.000000e+03     8.000000e+03  9.490000e+00
# 50%          NaN  1.290000e+04  1.287500e+04     1.280000e+04  1.262000e+01
# 75%          NaN  2.000000e+04  2.000000e+04     2.000000e+04  1.599000e+01
# max          NaN  4.000000e+04  4.000000e+04     4.000000e+04  3.099000e+01
#
#         installment    annual_inc           dti   delinq_2yrs  fico_range_low  \
# ...

# %%
missing = df.isnull().sum()
missing_percent = (missing / len(df)) * 100
missing_df = pd.DataFrame({'Missing': missing, 'Percent': missing_percent})
missing_df[missing_df['Missing'] > 0].sort_values('Percent', ascending=False)
# Out:
#                                             Missing     Percent
# member_id                                   2260701  100.000000
# orig_projected_additional_accrued_interest  2252050   99.617331
# hardship_payoff_balance_amount              2249784   99.517097
# hardship_last_payment_amount                2249784   99.517097
# payment_plan_start_date                     2249784   99.517097
# ...                                             ...         ...
# total_rec_int                                    33    0.001460
# total_rec_prncp                                  33    0.001460
# hardship_flag                                    33    0.001460
# disbursement_method                              33    0.001460
# debt_settlement_flag                             33    0.001460
#
# [150 rows x 2 columns]

# %%
unique_counts = df.nunique().sort_values()
unique_counts.head(10)
# Out:
# member_id              0
# policy_code            1
# deferral_term          1
# hardship_type          1
# hardship_length        1
# initial_list_status    2
# pymnt_plan             2
# term                   2
# hardship_flag          2
# application_type       2
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

# Income
threshold = df['annual_inc'].quantile(0.99)
filtered = df[df['annual_inc'] <= threshold]

filtered['annual_inc'].hist(bins=50, figsize=(8, 6))
plt.title("Annual Income (Capped at 99th Percentile)")
plt.xlabel("Annual Income")
plt.ylabel("Frequency")
plt.show()


# Loan amount
df['loan_amnt'].describe()

# Grade
df['grade'].value_counts(normalize=True)

# Loan status
df['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: count, dtype: int64

# %%
df[df['loan_amnt'] <= 0]
df[df['fico_range_high'] > 850]
# Out:
# Empty DataFrame
# ...

# %%
keep_cols = [
    'id', 'loan_amnt', 'term', 'int_rate', 'grade', 'emp_length',
    'home_ownership', 'annual_inc', 'loan_status', 'purpose',
    'addr_state', 'dti', 'fico_range_low', 'fico_range_high'
]
df[keep_cols].to_csv('../data/loan_cleaned.csv', index=False)
